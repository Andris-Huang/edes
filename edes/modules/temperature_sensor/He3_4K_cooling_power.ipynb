# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from scipy.optimize import curve_fit
from edes.modules.detection.detection_utils import plot, plot_ax, plot_ax_errbar, plot_errbar, big_plt_font, hollow_plt_font
hollow_plt_font()

# %%
# Heater Power (mW)
heater_power = np.array([0, 10, 20, 30, 40, 60, 85])

# Trap temp (K)
trap_temp = np.array([3.057, 3.35, 3.6, 3.835, 4.06, 4.466, 4.922])

# 4K plate temp (K)
plate_temp_4k = np.array([3.058, 3.086, 3.094, 3.115, 3.133, 3.166, 3.211])

# %%
plot(heater_power, trap_temp, label='Trap') 
plot(heater_power, plate_temp_4k, label='4K stage', xlabel='Applied power (mW)', ylabel='Temperature (K)')

# %%
# Temp (mK)
temp_mk = np.array([409.0, 428.67, 543.19, 629.23, 646.68])

# Heater Power (mW)
heater_power_mw = np.array([0.0, 0.1, 5.0, 10.0, 15.0]) 

plot(heater_power_mw, temp_mk, label='0.4K stage', xlabel='Applied power (mW)', ylabel='Temperature (mK)')
