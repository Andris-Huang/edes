# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from scipy.optimize import curve_fit
import warnings
from edes.modules.detection.detection_utils import plot, plot_ax, plot_ax_errbar, plot_errbar, big_plt_font
big_plt_font()

# %%
V_app = np.array([100, 200, 300, 400,500,600,700]) 
V_meas = np.array([-0.0001, -0.030,-3.7,-26.6,-70, -128,-180])
R = 0.985e6
V_pos = np.array([100,
200,
300,
400,
500,
600,
700,
800,
900,
1000,
1100,
1200,
1300])
V_meas_pos = np.array([1.0,
2.2,
3.4,
4.7,
5.6,
6.5,
7.4,
8.5,
9.5,
10.5,
11.4,
12.5,
13.5])

# %%
plot(V_pos, abs(V_meas_pos)/R*1e6, '.--', label='Positive voltage')
plot(V_app, abs(V_meas)/R*1e6, '.--', label='Negative voltage', xlabel='Voltage (V)', ylabel='Current (uA)')
plt.legend() 
plt.show()
