# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import os 
from edes.modules.detection.detection_utils import plot, plot_ax, big_plt_font
big_plt_font()

# %%
base = '/home/electron-cryo/Downloads'
def plot_counts(file):
    df = pd.read_csv(f'{base}/{file}.txt', sep=r'\t')
    t, counts = df['x(ps)'], df['counts']
    plot(t/1e12, counts/1e3, xlabel='Time (s)', ylabel='Counts/s')

# %%
plot_counts('Counter-2_2026-03-06_15-28-13')
# Out:
# /tmp/ipykernel_4092535/3800416548.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(f'{base}/{file}.txt', sep=r'\t')
