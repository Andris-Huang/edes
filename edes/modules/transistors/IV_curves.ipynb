# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd 
from edes.modules.detection.detection_utils import plot, plot_ax, plot_ax_errbar, big_plt_font

# %%
df = pd.read_csv("~/edes/data/20260312 JC group_HEMT IdVg/_DC_ID_VD_0V_to_2p5V_VGS_0to-800mV.csv", skiprows=257, usecols=range(1,6))

# %%
for i in ID: 
    if i == 'IGabs': 
        print(i)

# %%
ID, VD = np.array(df[' ID'], dtype=np.float32), np.array(df[' VD'], dtype=np.float32)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 ID, VD = np.array(df[' ID'], dtype=np.float32), np.array(df[' VD'], dtype=np.float32)
#
# File ~\miniconda3\envs\e\lib\site-packages\pandas\core\series.py:893, in Series.__array__(self, dtype)
#     846 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#     847     """
#     848     Return the values as a NumPy array.
#     849
#    (...)
#     891           dtype='datetime64[ns]')
#     892     """
# --> 893     return np.asarray(self._values, dtype)
#
# ValueError: could not convert string to float: ' IGabs'

# %%
ID

# %%
plot(VD, ID)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 plot(VD, ID)
#
# File c:\users\electron\edes\edes\modules\detection\detection_utils.py:34, in plot(x, y, xlabel, ylabel, title, *args, **kwargs)
#      33 def plot(x, y, *args, xlabel=None, ylabel=None, title=None, **kwargs):
# ---> 34     plt.plot(x, y, *args, **kwargs)
#      35     plt.grid(True)
#      36     plt.xlabel(xlabel)
#
# File ~\miniconda3\envs\e\lib\site-packages\matplotlib\pyplot.py:2748, in plot(scalex, scaley, data, *args, **kwargs)
#    2746 @_copy_docstring_and_deprecators(Axes.plot)
#    2747 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2748     return gca().plot(
#    2749         *args, scalex=scalex, scaley=scaley,
#    2750         **({"data": data} if data is not None else {}), **kwargs)
#
# ...
