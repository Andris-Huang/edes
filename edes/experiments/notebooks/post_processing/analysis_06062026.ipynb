# %%
import edes 
from edes.utils.plotting import plot, plot_ax, big_plt_font, plot_ax_errbar, plot_errbar
import numpy as np 
from tqdm import tqdm, trange 
import matplotlib.pyplot as plt 
import time
from edes.utils.file_handling import load_h5_data, load_latest_data, load_latest_filename
big_plt_font()

# %%
file = load_latest_data() 
plot_errbar(file['all_V'], -np.mean(file['all_I'], axis=1)*1e6, yerr=np.std(file['all_I'], axis=1)*1e6, fmt='.--', xlabel='Tip voltage (V)', ylabel='Electrode current (nA)')
# plt.yscale('log')

# %%
file.items()
# Out:
# dict_items([('FEtip_PSU', b'PS350_viaDP832A'), ('N_avg', np.int64(8)), ('R', np.float64(100000000.0)), ('V_start', np.int64(1000)), ('V_step', np.int64(200)), ('V_stop', np.int64(3000)), ('all_I', array([[-4.08247125e-10, -4.05298509e-10, -3.99036144e-10,
#         -3.95936090e-10, -3.92269741e-10, -3.86332460e-10,
#         -3.68232456e-10, -3.79577053e-10],
#        [-1.25225809e-09, -2.10874053e-08, -1.16772811e-09,
#         -1.11637796e-09, -1.10966888e-09, -1.06086372e-09,
#         -1.04251773e-09, -1.03380715e-09],
#        [-3.93058493e-08, -3.96970203e-08, -4.43001250e-08,
#         -3.38972116e-08, -6.09092264e-09, -6.48268064e-09,
#         -7.91969673e-09, -5.95638521e-09],
#        [-2.37845537e-07, -2.44393262e-07, -2.51823287e-07,
#         -2.25319987e-07, -2.65988556e-07, -2.28621141e-07,
#         -2.13702240e-07, -2.07508574e-07],
#        [-3.98116612e-07, -4.19859800e-07, -4.12512514e-07,
#         -4.08646978e-07, -4.04635277e-07, -4.12404203e-07,
#         -4.01723840e-07, -3.96771353e-07],
#        [-5.80607981e-07, -5.58238605e-07, -5.90755239e-07,
#         -5.59869852e-07, -5.73245911e-07, -5.68154956e-07,
#         -5.80728153e-07, -5.75405196e-07],
#        [-7.32548682e-07, -7.81192780e-07, -8.17586607e-07,
#         -8.01864863e-07, -8.36769403e-07, -8.33720791e-07,
#         -8.12633126e-07, -8.29480468e-07],
#        [-9.12356174e-07, -9.18343908e-07, -9.17247683e-07,
#         -9.10954767e-07, -9.14503646e-07, -9.11783613e-07,
#         -9.16579985e-07, -9.07180105e-07],
#        [-1.09039441e-06, -1.08233519e-06, -1.08933632e-06,
#         -1.08362844e-06, -1.07850332e-06, -1.07911600e-06,
#         -1.08432645e-06, -1.08688305e-06],
#        [-1.25402977e-06, -1.24786541e-06, -1.24791244e-06,
#         -1.24842977e-06, -1.25036407e-06, -1.25910385e-06,
#         -1.25288350e-06, -1.25368195e-06]])), ('all_V', array([1000, 1200, 1400, 1600, 1800, 2000, 2200, 2400, 2600, 2800])), ('multimeter', b'Agilent34461A'), ('t_PSU_settle', np.int64(2)), ('t_meas_delay', np.float64(0.2)), ('filename', '/home/electron/data/experiment_06062026/TipVoltageSweep_16-12-43.h5')])
