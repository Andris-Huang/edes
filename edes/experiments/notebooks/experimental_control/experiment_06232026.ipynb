# %%
import edes 
from edes.experiments import Experiment
from edes.utils.plotting import plot, plot_ax, big_plt_font, plot_ax_errbar, plot_errbar
from edes.utils.circuits import dBm_to_Vp, dBm_to_W, Vp_to_dBm
from edes.utils.utils import beep_jupyter
import numpy as np 
from tqdm import tqdm, trange 
import matplotlib.pyplot as plt 
import time
from edes.experiments.sequences.base import TipVoltageSweep, Sequence, RFPowerSweep, RigolAWGSweep, RFPowerSweepAWG, RFPowerSweepAWGTipSwitched
from edes.experiments.devices.base import Instrument
from edes.utils.file_handling import load_latest_data, load_lib
from typing import TYPE_CHECKING
from datetime import datetime

#from edes.utils.utils import beep_VS

# 1. This code block ONLY runs in your IDE for auto-complete
# It is completely ignored when the code actually runs
if TYPE_CHECKING:
    from edes.experiments.devices.base import *
big_plt_font()

# %%
exp = Experiment('3layer_trapping_062226')
# Out:
# >>> Connected to Rigol Technologies,DG4062,DG4E253802125,00.01.14
#
# >>> ERROR connecting to Agilent34461A at USB0::2391::7175::MY53200916::0::INSTR: No device found.
# >>> Connected to ARTIQ Zotino.
# >>> Connected to RIGOL TECHNOLOGIES,DP832A,DP8B260200018,00.01.19
#
# >>> ERROR connecting to Keithley2100 at USB0::1510::8448::1243106::0::INSTR: No device found.
# >>> Connected to Siglent Technologies,SPD3303X-E,SPD3XJEQ6R3773,1.01.01.02.07R2,V3.0
#
# >>> Connected to Siglent Technologies,SSA3032X-R,SSA5PA1Q800415,3.2.2.6.0R10
#
# >>> Connected to Valon at ASRL/dev/ttyUSB0::INSTR with frequency 1473950000.0 Hz and power 0 dBm.

# %%
RF_sweep = RFPowerSweepAWG(saving_dir=exp.saving_dir,
                           P_min_dBm=1, P_max_dBm=-6, P_hold_dBm=0, P_valon=6.0, 
                           ramp_time=2, hold_time=0.2, t_data_buffer=0.5, t_tip_settle=1.5, t_seq_gap=1,
                           N_avg=32, 
                           V_on=2150, V_off=1600, 
                           SSA_freq_center=None, SSA_freq_span=0, SSA_RBW = 10e3, # None goes to default value in config
                           AWG=exp.AWG, Valon=exp.Valon, SSA=exp.SSA, FEtip_PSU=exp.FEtip_PSU,
                           display_progress=True)

# %%
all_U2 = np.arange(-1, 1, 0.2)
all_Ex = np.arange(-1, 1, 0.2)
for Ex in all_Ex:
    for U2 in all_U2:
        RF_sweep.set_parameters(U2=U2)
        RF_sweep.set_parameters(Ex=Ex)
        exp.DAC.set_multipoles(Ex=Ex, U2=U2)
        file = RF_sweep.run_save()
        exp.DAC.ground_all() 
        time.sleep(60*5) 
exp.Valon.output_off()
exp.FEtip_PSU.ramp_down(0)
beep_jupyter()
# Out:
# RID: 9519
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [02:47<00:00,  5.24s/it]
# RID: 9520
# voltages loaded
# RID: 9521
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [02:47<00:00,  5.24s/it]
# RID: 9522
# voltages loaded
# RID: 9523
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [02:47<00:00,  5.24s/it]
# RID: 9524
# voltages loaded
# RID: 9525
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [02:47<00:00,  5.24s/it]
# RID: 9526
# voltages loaded
# RID: 9527
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [02:47<00:00,  5.24s/it]
# RID: 9528
# voltages loaded
# RID: 9529
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [02:47<00:00,  5.24s/it]
# RID: 9530
# voltages loaded
# RID: 9531
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [02:47<00:00,  5.25s/it]
# RID: 9532
# voltages loaded
# RID: 9533
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [02:47<00:00,  5.24s/it]
# RID: 9534
# voltages loaded
# RID: 9535
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [02:47<00:00,  5.24s/it]
# RID: 9536
# voltages loaded
# RID: 9537
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [02:47<00:00,  5.24s/it]
# RID: 9538
# voltages loaded
# RID: 9539
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [02:47<00:00,  5.24s/it]
# RID: 9540
# voltages loaded
# RID: 9541
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [02:47<00:00,  5.24s/it]
# RID: 9542
# voltages loaded
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 10
#       8         file = RF_sweep.run_save()
#       9         exp.DAC.ground_all()
# ---> 10         time.sleep(60*5)
#      11 exp.Valon.output_off()
#      12 exp.FEtip_PSU.ramp_down(0)
#
# KeyboardInterrupt:

# %%
all_U2 = np.arange(-0.5, 1, 0.5)
all_Ex = [0, -1, 1]
for Ex in all_Ex:
    for U2 in all_U2:
        RF_sweep.set_parameters(U2=U2)
        RF_sweep.set_parameters(Ex=Ex)
        exp.DAC.set_multipoles(Ex=Ex, U2=U2)
        file = RF_sweep.run_save()
        exp.DAC.ground_all() 
        time.sleep(60) 
exp.Valon.output_off()
exp.FEtip_PSU.ramp_down(0)
beep_jupyter()
# Out:
# RID: 9504
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [01:50<00:00,  3.44s/it]
# RID: 9505
# voltages loaded
# RID: 9506
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [01:50<00:00,  3.44s/it]
# RID: 9507
# voltages loaded
# RID: 9508
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [01:50<00:00,  3.44s/it]
# RID: 9509
# voltages loaded
# RID: 9510
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [01:50<00:00,  3.44s/it]
# RID: 9511
# voltages loaded
# RID: 9512
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [01:50<00:00,  3.44s/it]
# RID: 9513
# voltages loaded
# RID: 9514
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [01:50<00:00,  3.44s/it]
# RID: 9515
# voltages loaded
# RID: 9516
# voltages loaded
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 8
#       6 RF_sweep.set_parameters(Ex=Ex)
#       7 exp.DAC.set_multipoles(Ex=Ex, U2=U2)
# ----> 8 file = RF_sweep.run_save()
#       9 exp.DAC.ground_all()
#      10 time.sleep(60)
#
# File ~/edes/edes/experiments/sequences/base.py:56, in Sequence.run_save(self)
#      55 def run_save(self):
# ---> 56     result = self.run()
#      57     timestamp = time.strftime('%H-%M-%S')
#      58     filepath = f"{self.saving_dir}/{self.name}_{timestamp}.h5"
#
# File ~/edes/edes/experiments/sequences/base.py:376, in RFPowerSweepAWG.run(self)
#     374 self.SSA.trigger_on()
#     375 self.AWG_sweep.run()
# --> 376 time.sleep(self.AWG_sweep.running_time)
#     377 self.SSA.get_trace()
#     378 time.sleep(1)
#
# KeyboardInterrupt:

# %%
RF_sweep = RFPowerSweepAWGTipSwitched(saving_dir=exp.saving_dir,
                           P_min_dBm=0, P_max_dBm=-6, P_hold_dBm=0, P_valon=5.0, 
                           ramp_time=1, hold_time=0.2, t_data_buffer=0.2, t_tip_settle=3, t_seq_gap=6,
                           N_avg=64, 
                           V_on=2150, V_off=1600, 
                           SSA_freq_center=None, SSA_freq_span=0, SSA_RBW = 30e3, # None goes to default value in config
                           AWG=exp.AWG, Valon=exp.Valon, SSA=exp.SSA, FEtip_PSU=exp.FEtip_PSU,
                           display_progress=True)

# %%
t_tip_settle
# Out:
# 10

# %%
now = datetime.now()
print(f">>> Starting time: {now:%Y-%m-%d %H:%M:%S}")

for t_tip_settle in [10]:
    RF_sweep = RFPowerSweepAWGTipSwitched(saving_dir=exp.saving_dir,
                           P_min_dBm=0, P_max_dBm=-6, P_hold_dBm=0, P_valon=5.0, 
                           ramp_time=1, hold_time=0.2, t_data_buffer=0.2, t_tip_settle=t_tip_settle, t_seq_gap=t_tip_settle+2,
                           N_avg=32, 
                           V_on=2150, V_off=1600, 
                           SSA_freq_center=None, SSA_freq_span=0, SSA_RBW = 30e3, # None goes to default value in config
                           AWG=exp.AWG, Valon=exp.Valon, SSA=exp.SSA, FEtip_PSU=exp.FEtip_PSU,
                           display_progress=True)
    all_U2 = [-1, -0.7, -0.4, -0.2, 0, 0.5]
    all_Ex = [-1, -0.5, 0, 0.5]
    for Ex in all_Ex:
        for U2 in all_U2:
            RF_sweep.set_parameters(U2=U2)
            RF_sweep.set_parameters(Ex=Ex)
            exp.DAC.set_multipoles(Ex=Ex, U2=U2)
            file = RF_sweep.run_save()
            exp.DAC.ground_all() 
            time.sleep(30) 
exp.Valon.output_off()
exp.FEtip_PSU.ramp_down(0)
beep_jupyter()
# Out:
# >>> Starting time: 2026-06-24 09:24:30
# RID: 9644
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [12:37<00:00, 23.66s/it]
# RID: 9645
# voltages loaded
# RID: 9646
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [12:37<00:00, 23.66s/it]
# RID: 9647
# voltages loaded
# RID: 9648
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [12:37<00:00, 23.66s/it]
# RID: 9649
# voltages loaded
# RID: 9650
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [12:37<00:00, 23.66s/it]
# RID: 9651
# voltages loaded
# RID: 9652
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [12:37<00:00, 23.66s/it]
# RID: 9653
# voltages loaded
# RID: 9654
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [12:37<00:00, 23.66s/it]
# RID: 9655
# voltages loaded
# RID: 9656
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [12:37<00:00, 23.66s/it]
# RID: 9657
# voltages loaded
# RID: 9658
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [12:37<00:00, 23.66s/it]
# RID: 9659
# voltages loaded
# RID: 9660
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [12:37<00:00, 23.66s/it]
# RID: 9661
# voltages loaded
# RID: 9662
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [12:37<00:00, 23.66s/it]
# RID: 9663
# voltages loaded
# RID: 9664
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [12:37<00:00, 23.66s/it]
# RID: 9665
# voltages loaded
# RID: 9666
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [12:37<00:00, 23.66s/it]
# RID: 9667
# voltages loaded
# RID: 9668
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [12:37<00:00, 23.66s/it]
# RID: 9669
# voltages loaded
# RID: 9670
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [12:37<00:00, 23.66s/it]
# RID: 9671
# voltages loaded
# RID: 9672
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [12:37<00:00, 23.66s/it]
# RID: 9673
# voltages loaded
# RID: 9674
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [12:37<00:00, 23.66s/it]
# RID: 9675
# voltages loaded
# RID: 9676
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [12:37<00:00, 23.66s/it]
# RID: 9677
# voltages loaded
# RID: 9678
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [12:37<00:00, 23.66s/it]
# RID: 9679
# voltages loaded
# RID: 9680
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [12:36<00:00, 23.66s/it]
# RID: 9681
# voltages loaded
# RID: 9682
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [12:37<00:00, 23.66s/it]
# RID: 9683
# voltages loaded
# RID: 9684
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [12:37<00:00, 23.66s/it]
# RID: 9685
# voltages loaded
# RID: 9686
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [12:37<00:00, 23.66s/it]
# RID: 9687
# voltages loaded
# RID: 9688
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [12:37<00:00, 23.66s/it]
# RID: 9689
# voltages loaded
# RID: 9690
# voltages loaded
# 100%|███████████████████████████████████████████| 32/32 [12:37<00:00, 23.66s/it]
# RID: 9691
# voltages loaded

# %%
data = file['all_meas'] 
t_start = file['t_tip_on']
t_sweep_start = file['t_sweep_start'] - t_start
t_sweep_end = file['t_sweep_end'] - t_start 
t_tip_off = file['t_tip_off'] - t_start
t_seq_end = file['t_seq_end'] - t_start 
data_avg = np.mean(data, axis=0) 
fig, ax = plt.subplots(ncols=2, figsize=(12,4))
t_axis = np.linspace(0, t_seq_end[-1], len(data_avg)) 
T_zoom_expansion = max(2*(t_tip_off[-1] - t_sweep_end[-1]), 0.01)
plot_ax(ax[0], t_axis, data_avg, xlabel='Time (s)', ylabel='Power (dBm)')
plot_ax(ax[1], t_axis, data_avg, xlabel='Time (s)')
ax[0].axvline(t_sweep_start[-1], linestyle='--', c='C1', label='Sweep Start')
ax[0].axvline(t_sweep_end[-1], linestyle='--', c='C2', label='Sweep End') 
ax[0].axvline(t_tip_off[-1], linestyle='--', c='C3', label='Tip Off') 
ax[1].axvline(t_sweep_start[-1], linestyle='--', c='C1', label='Sweep Start')
ax[1].axvline(t_sweep_end[-1], linestyle='--', c='C2', label='Sweep End') 
ax[1].axvline(t_tip_off[-1], linestyle='--', c='C3', label='Tip Off') 
ax[1].set_xlim((t_sweep_start[-1]-T_zoom_expansion, t_tip_off[-1]+T_zoom_expansion))
ax[1].legend(bbox_to_anchor=(1,1))
plt.tight_layout()
plt.show()

# %%
exp.Valon.output_off()

# %%
tip_Vsweep = TipVoltageSweep(saving_dir=exp.saving_dir, 
                             V_start=800, V_stop=2200, V_step=100, R=100e6, 
                             N_avg=8, t_PSU_settle=2, t_meas_delay=0.2, 
                             FEtip_PSU=exp.FEtip_PSU, multimeter=exp.Keithley)

# %%
file = tip_Vsweep.run_save()
# Out:
# 100%|███████████████████████████████████████████| 14/14 [00:53<00:00,  3.85s/it]

# %%
plot_errbar(file['all_V'], np.mean(file['all_I'], axis=1)*1e9, yerr=np.std(file['all_I'], axis=1)*1e9, fmt='.--', xlabel='Tip voltage (V)', ylabel='Electrode current (nA)')
# plt.yscale('log')

# %%
tip_Vsweep = TipVoltageSweep(name='bl3_current_withtip_others_floating',saving_dir=exp.saving_dir, 
                             V_start=1400, V_stop=2400, V_step=50, R=100e6, 
                             N_avg=10, t_PSU_settle=5, t_meas_delay=1, 
                             FEtip_PSU=exp.FEtip_PSU, multimeter=exp.Keithley)

# %%
file = tip_Vsweep.run_save()

# %%
plot_errbar(file['all_V'], -np.mean(file['all_I'], axis=1)*1e12, yerr=np.std(file['all_I'], axis=1)*1e12, fmt='.--', xlabel='Tip voltage (V)', ylabel='Electrode current (pA)')
# plt.yscale('log')

# %%
exp.FEtip_PSU.ramp_down(0)

# %%
exp.DAC.set_multipoles(U2=-0.4)
# Out:
# RID: 9419
# voltages loaded
