# %%
# from lakeshore import Model240, Model240InputParameter, Model240CurveHeader
import pynanovna
from pynanovna.utils import stream_from_csv
from pynanovna.vis import plot, polar
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import warnings
import time
import datetime
import os
from scipy.optimize import curve_fit
import warnings
import requests
import json
from edes.modules.detection.detection_utils import plot, plot_ax, plot_ax_errbar, plot_errbar, big_plt_font
big_plt_font()
warnings.filterwarnings('once')

vna = pynanovna.VNA()
vna.load_calibration("/home/electron/edes/edes/modules/VNA/Calibration_1783984474.720992.cal") # calibration using port 12, 13 with cryo wires
# Out:
# 2026-07-13 17:50:57,011 - root - INFO - Initializing the VNA.
# 2026-07-13 17:51:01,372 - root - INFO - VNA successfully initialized.
# 2026-07-13 17:51:01,587 - root - INFO - Calibration successfully enabled.

# %%
def S21(f,f0,Q,Qc,a,t):
    #constant phase offset
    phase1 = np.exp(1j*0)
    #frequency dependent phase
    phase2 = np.exp(-2*np.pi*1j*f*0)
    #ideal resonator
    F = (Q/Qc)/(1+2*1j*Q*(f-f0)/f0)

    #real and imaginary components
    S21_complex = phase1*phase2*F
    S21_re = np.real(S21_complex)
    S21_im = np.imag(S21_complex)

    return np.concatenate((S21_re,S21_im))

def S11(f,f0,Q,Qc,a,t):
    #constant phase offset
    phase1 = np.exp(1j*0)
    #frequency dependent phase
    phase2 = np.exp(-2*np.pi*1j*f*0)
    #ideal resonator
    F = (1 - 2*(Q/Qc)/(1+2*1j*Q*(f-f0)/f0))

    #real and imaginary components
    S21_complex = phase1*phase2*F
    S21_re = np.real(S21_complex)
    S21_im = np.imag(S21_complex)

    return np.concatenate((S21_re,S21_im))

def vec_S21(S21_concat):
    l = int(len(S21_concat)/2)
    r = S21_concat[:l]
    i = S21_concat[l:]
    return [r,i]

def vec_S11(S11_concat):
    l = int(len(S11_concat)/2)
    r = S11_concat[:l]
    i = S11_concat[l:]
    return [r,i]

def mag_S21(re_s21, im_s21):
    return (np.sqrt(re_s21**2+im_s21**2))

def phase_S21(re_s21, im_s21):
    return np.arctan(im_s21/re_s21)

def get_Qi(Q, Qc):
    return 1 / (1/Q - 1/Qc)

def fit_S21(s2p_file, pi = [270e6,500,1000,0,0], C='blue', slabel='', start=185e6, stop=205e6):
  filepath = s2p_file
  df = pd.read_csv(filepath,skiprows=6,names=['S11', 'S21', 'freq'])

  freqs_np = np.array(df.freq)
  ReS21 = np.array(df['S21']).astype(complex).real
  ImS21 = np.array(df['S21']).astype(complex).imag

  magS21 = np.sqrt(ReS21**2+ImS21**2)

  

  max_freq = (freqs_np[np.where(magS21==np.max(magS21))])

  start = 250e6  #max_freq[0]-3e6
  stop= 300e6  #max_freq[0]+3e6


  min_index = np.min(np.where(freqs_np>=start)[0])
  max_index = np.max(np.where(freqs_np<=stop)[0])


  reS21_np = np.array(ReS21)[min_index:max_index]
  imS21_np = np.array(ImS21)[min_index:max_index]
  freqs=freqs_np[min_index:max_index]
  pi[0] = max_freq[0] 
    

  S21_data = np.concatenate((reS21_np,imS21_np))

  params, pcov = curve_fit(S21, freqs, S21_data,p0=pi)

  S21_Concat = S21(freqs,params[0],params[1],params[2],0,0)#,params[3],params[4])
  S21_Vec = vec_S21(S21_Concat)

  #plt.plot(freqs/1e6, mag_S21(S21_Vec[0],S21_Vec[1]),'.',color='r', label=f'Q = {round(params[1],2)}')

  S21_mags = np.sqrt(S21_Vec[0]**2+S21_Vec[1]**2)

  plt.plot(freqs/1e6,S21_mags,color=C, label=slabel+f'Q = {round(params[1],2)}')
  plt.xlabel('frequency (MHZ)')
  plt.ylabel('mag(S21)')
  plt.legend()

  
  return params

def fit_S11(s2p_file, pi = [227e6,200,100,0,0], C='blue', slabel='', start=185e6, stop=205e6):
  filepath = s2p_file
  #df = pd.read_csv(filepath,skiprows=6,names=['S11', 'S21', 'freq'])
  df = pd.read_csv(filepath)

  freqs_np = np.array(df['freq'], dtype=np.float64)
  ReS11 = np.array(df['S11'], dtype=np.complex128).real
  ImS11 = np.array(df['S11'], dtype=np.complex128).imag

  print(np.shape(ReS11))

  magS11 = np.sqrt(ReS11**2+ImS11**2)

  

  max_freq = (freqs_np[np.where(magS11==np.max(magS11))])

  start = 210e6  #max_freq[0]-3e6
  stop= 250e6  #max_freq[0]+3e6


  min_index = np.min(np.where(freqs_np>=start)[0])
  max_index = np.max(np.where(freqs_np<=stop)[0])


  reS11_np = np.array(ReS11)[min_index:max_index]
  imS11_np = np.array(ImS11)[min_index:max_index]
  freqs=freqs_np[min_index:max_index]
  pi[0] = max_freq[0] 
    

  S11_data = np.concatenate((reS11_np,imS11_np))

  params, pcov = curve_fit(S11, freqs, S11_data,p0=pi)

  S11_Concat = S11(freqs,params[0],params[1],params[2],0,0)#,params[3],params[4])
  #S11_Concat = S11(freqs,pi[0],pi[1],pi[2],0,0)#,params[3],params[4])
  S11_Vec = vec_S11(S11_Concat)

  #plt.plot(freqs/1e6, mag_S21(S21_Vec[0],S21_Vec[1]),'.',color='r', label=f'Q = {round(params[1],2)}')

  S11_mags = np.sqrt(S11_Vec[0]**2+S11_Vec[1]**2)

  plt.plot(freqs/1e6,S11_mags,color=C, label=slabel+f'Q = {round(params[1],2)}')
  plt.plot(freqs/1e6, magS11[min_index:max_index])
  plt.xlabel('frequency (MHZ)')
  plt.ylabel('mag(S11)')
  plt.legend()
  return params

# %%
#initialize VNA
def vna_sweep(vna, sweep_range,num_points,path,default=101):

    # default = 101

    start = sweep_range[0]
    stop = sweep_range[1]
    point_range = stop-start


    if num_points>default:
        S11 = []
        S21 = []
    
        num_sweeps = int((num_points - num_points%default)/default + 1) #number of sweeps required 
        # print(f'doing {num_sweeps-1} sweeps of {default} points and 1 sweep of  {num_points%default} to achieve {num_points} points')
        sub_sweep = point_range/num_sweeps 

        
        
        S11_sweeps = []
        S21_sweeps = []
        freq_sweeps = []
        
        for i in range(1, num_sweeps):
            freq = np.linspace(start+(i-1)*sub_sweep, start+i*sub_sweep, default)
            # print(min(freq), max(freq), len(freq))
            vna.set_sweep(min(freq), max(freq), len(freq))
            stream = vna.stream()
            data0, data1, freq = vna.sweep()
            
            S11_sweeps.append(data0)
            S21_sweeps.append(data1)
            freq_sweeps.append(freq)

        freq = np.linspace(start+(num_sweeps-1)*sub_sweep, start+num_sweeps*sub_sweep,  num_points%default)
        # print(min(freq), max(freq), len(freq))
        
        vna.set_sweep(min(freq), max(freq), len(freq))
        stream = vna.stream()
        time.sleep(1)
        data0, data1, freq = vna.sweep()
        time.sleep(1)
        S11_sweeps.append(data0)
        S21_sweeps.append(data1)
        freq_sweeps.append(freq)

        S11_data = np.concatenate(S11_sweeps)
        S21_data = np.concatenate(S21_sweeps)
        freq_data = np.concatenate(freq_sweeps)

        data = {'S11': S11_data, 'S21': S21_data, 'freq': freq_data }
        df = pd.DataFrame(data)
        df.to_csv(path, index=False)

    else:
        #vna sweep
        vna.set_sweep(start, stop, num_points)
        stream = vna.stream()
        S11_data, S21_data, freq_data = vna.sweep()

        data = {'S11': S11_data, 'S21': S21_data, 'freq': freq_data }
        df = pd.DataFrame(data)
        df.to_csv(path, index=False)
        #filename = path
        #vna.stream_to_csv(filename, 1)

    return S11_data, S21_data, freq_data

def vna_plot(path):
    #plot VNA data
    df = pd.read_csv(path,skiprows = 7,names=['S11','S21','freq'])
    
    S11 = np.array(df['S11'])
    S21 = np.array(df['S21'])
    freq = np.array(df['freq'])

    '''
    #find the row that doesnt have data
    bad_index = np.where(S11=='sweepnumber: ')[0][0]
    '''
    bad_index = -1
    #get rid of bad row1 
    S11_clean = np.array(S11[bad_index+1:]).astype(complex)
    S21_clean = np.array(S21[bad_index+1:]).astype(complex)
    freq_clean = np.array(freq[bad_index+1:])
    S11_mag_db = 20*np.log10(np.abs(S11_clean))
    S21_mag_db = 20*np.log10(np.abs(S21_clean))
    
    plt.plot(freq_clean*1e-6,S11_mag_db,'.',label='S11', color='blue')
    plt.plot(freq_clean*1e-6,S11_mag_db,alpha=0.2, color='blue')
    plt.xlabel('frequency (MHz)')
    plt.ylabel('S11 (dB)')
    '''
    res = (freq_clean[np.where(S21_mag_db==max(S21_mag_db))])*1e-6
    plt.plot(freq_clean*1e-6,S21_mag_db,'.',label='S21', color='blue')
    #plt.plot(freq_clean*1e-6,S21_mag_db,alpha=0.2, color='blue')
    plt.xlabel('frequency (MHz)')
    plt.ylabel('S21 (dB)')
    '''
    res = (freq_clean[np.where(S21_mag_db==max(S21_mag_db))])*1e-6
    plt.title(path)
    plt.legend()

# %%
def take_vna_sweep(filename, folder_path, f_begin, f_end, vna, N_points=2000): 
    os.makedirs(folder_path, exist_ok=True)
    file_path = os.path.join(folder_path,filename)
    S11_0, S21_0, freq = vna_sweep(vna, (f_begin, f_end), N_points, file_path)
    return S11_0, S21_0, freq

# %%
def query_temp(stage, T_to_channels = {'40K': 1, '4K': 2, '0.4K': 5}): 
    req = requests.get('http://192.168.169.102:5001/channel/measurement/latest', timeout=10)
    data = req.json()
    ch = T_to_channels[stage]
    while data['channel_nr'] != ch: 
        req = requests.get('http://192.168.169.102:5001/channel/measurement/latest', timeout=10)
        data = req.json()
    return data['temperature']

# %%
base = "/home/electron/data/glass_trap_07132026"

# %%
import time
timestamp = time.strftime('%H-%M-%S')
filename = f'glass_trap_{timestamp}.csv'
folder_path = base
S11_0, S21_0, freq = take_vna_sweep(filename, folder_path, 1e9, 6.3e9, vna, N_points=3251)
# Out:
# 2026-07-13 17:53:30,483 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1000000000 step 1606060
# 2026-07-13 17:53:30,880 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1160606060 step 1606060
# 2026-07-13 17:53:31,558 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1321212121 step 1606060
# 2026-07-13 17:53:32,247 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1481818181 step 1606060
# 2026-07-13 17:53:32,920 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1642424242 step 1606060
# 2026-07-13 17:53:33,605 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1803030303 step 1606060
# 2026-07-13 17:53:34,292 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1963636363 step 1606060
# 2026-07-13 17:53:34,981 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2124242424 step 1606060
# 2026-07-13 17:53:35,654 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2284848484 step 1606060
# 2026-07-13 17:53:36,331 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2445454545 step 1606060
# 2026-07-13 17:53:37,009 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2606060606 step 1606060
# 2026-07-13 17:53:37,685 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2766666666 step 1606060
# 2026-07-13 17:53:38,363 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2927272727 step 1606060
# 2026-07-13 17:53:39,037 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3087878787 step 1606060
# 2026-07-13 17:53:39,710 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3248484848 step 1606060
# 2026-07-13 17:53:40,383 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3409090909 step 1606060
# 2026-07-13 17:53:41,057 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3569696969 step 1606060
# 2026-07-13 17:53:41,734 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3730303030 step 1606060
# 2026-07-13 17:53:42,421 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3890909090 step 1606060
# 2026-07-13 17:53:43,107 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 4051515151 step 1606060
# 2026-07-13 17:53:43,795 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 4212121212 step 1606060
# 2026-07-13 17:53:44,473 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 4372727272 step 1606060
# 2026-07-13 17:53:45,156 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 4533333333 step 1606060
# 2026-07-13 17:53:45,838 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 4693939393 step 1606060
# 2026-07-13 17:53:46,526 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 4854545454 step 1606060
# 2026-07-13 17:53:47,211 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 5015151515 step 1606060
# 2026-07-13 17:53:47,898 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 5175757575 step 1606060
# 2026-07-13 17:53:48,582 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 5336363636 step 1606060
# 2026-07-13 17:53:49,259 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 5496969696 step 1606060
# 2026-07-13 17:53:49,936 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 5657575757 step 1606060
# 2026-07-13 17:53:50,611 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 5818181818 step 1606060
# 2026-07-13 17:53:51,291 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 5978787878 step 1606060
# 2026-07-13 17:53:51,979 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 6139393939 step 8922558

# %%
plot(freq/1e9, 20*np.log10(np.abs(S11_0)), label='S11', xlabel='Frequency (GHz)', ylabel='|S| (dB)')
plot(freq/1e9, 20*np.log10(np.abs(S21_0)), label='S21', xlabel='Frequency (GHz)', ylabel='|S| (dB)')
plt.legend() 
plt.show()

# %%
folder_path = base #+ r'warmup_02192026_trap'
os.makedirs(folder_path, exist_ok=True)
temp_list = list(range(290,4,-2))
query_period = 15 # s 
timeout_0 = 100 # N x query period

timeout = timeout_0
curr_T_i = 0 
while curr_T_i < len(temp_list) and timeout > 0: 
    curr_T = query_temp("0.4K") 
    if curr_T <= temp_list[curr_T_i]: 
        filename = f'{curr_T}.csv'
        try:
            S11_0, S21_0, freq = take_vna_sweep(filename, folder_path, 1e9, 3.3e9, vna, N_points=2301)
            plot(freq/1e9, 20*np.log10(abs(S11_0)), label='S11', xlabel='Frequency (GHz)', ylabel='|S| (dB)')
            plot(freq/1e9, 20*np.log10(abs(S21_0)), label='S21', xlabel='Frequency (GHz)', ylabel='|S| (dB)', title=f'{curr_T}K')
            plt.legend() 
            plt.show()
            curr_T_i += 1 
            timeout = timeout_0
        except: 
            print(">>> Serial exception caught, sleep for 1s and continuing")
            time.sleep(1)
    else: 
        time.sleep(query_period) 
        timeout -= 1
        if timeout == 0: 
            print(f">>> Temperature cannot reach the desired {temp_list[curr_T_i]}K limit in {timeout_0} queries, current temperature {curr_T:.2f}K")
# Out:
# 2026-07-13 18:04:56,036 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1000000000 step 1000000
# 2026-07-13 18:04:56,436 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1100000000 step 1000000
# 2026-07-13 18:04:57,123 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1200000000 step 1000000
# 2026-07-13 18:04:57,811 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1300000000 step 1000000
# 2026-07-13 18:04:58,489 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1400000000 step 1000000
# 2026-07-13 18:04:59,172 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1500000000 step 1000000
# 2026-07-13 18:04:59,849 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1600000000 step 1000000
# 2026-07-13 18:05:00,537 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1700000000 step 1000000
# 2026-07-13 18:05:01,226 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1800000000 step 1000000
# 2026-07-13 18:05:01,901 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1900000000 step 1000000
# 2026-07-13 18:05:02,581 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2000000000 step 1000000
# 2026-07-13 18:05:03,269 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2100000000 step 1000000
# 2026-07-13 18:05:03,953 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2200000000 step 1000000
# 2026-07-13 18:05:04,633 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2300000000 step 1000000
# 2026-07-13 18:05:05,309 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2400000000 step 1000000
# 2026-07-13 18:05:05,997 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2500000000 step 1000000
# 2026-07-13 18:05:06,681 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2600000000 step 1000000
# 2026-07-13 18:05:07,360 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2700000000 step 1000000
# 2026-07-13 18:05:08,037 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2800000000 step 1000000
# 2026-07-13 18:05:08,721 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2900000000 step 1000000
# 2026-07-13 18:05:09,414 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3000000000 step 1000000
# 2026-07-13 18:05:10,103 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3100000000 step 1000000
# 2026-07-13 18:05:10,801 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3200000000 step 1282051
# 2026-07-13 18:05:30,240 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1000000000 step 1000000
# 2026-07-13 18:05:30,641 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1100000000 step 1000000
# 2026-07-13 18:05:31,324 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1200000000 step 1000000
# 2026-07-13 18:05:32,007 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1300000000 step 1000000
# 2026-07-13 18:05:32,687 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1400000000 step 1000000
# 2026-07-13 18:05:33,372 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1500000000 step 1000000
# 2026-07-13 18:05:34,050 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1600000000 step 1000000
# 2026-07-13 18:05:34,740 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1700000000 step 1000000
# 2026-07-13 18:05:35,416 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1800000000 step 1000000
# 2026-07-13 18:05:36,095 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1900000000 step 1000000
# 2026-07-13 18:05:36,773 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2000000000 step 1000000
# 2026-07-13 18:05:37,463 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2100000000 step 1000000
# 2026-07-13 18:05:38,140 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2200000000 step 1000000
# 2026-07-13 18:05:38,826 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2300000000 step 1000000
# 2026-07-13 18:05:39,499 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2400000000 step 1000000
# 2026-07-13 18:05:40,173 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2500000000 step 1000000
# 2026-07-13 18:05:40,846 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2600000000 step 1000000
# 2026-07-13 18:05:41,527 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2700000000 step 1000000
# 2026-07-13 18:05:42,217 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2800000000 step 1000000
# 2026-07-13 18:05:42,917 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2900000000 step 1000000
# 2026-07-13 18:05:43,603 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3000000000 step 1000000
# 2026-07-13 18:05:44,297 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3100000000 step 1000000
# 2026-07-13 18:05:44,974 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3200000000 step 1282051
# 2026-07-13 18:06:04,634 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1000000000 step 1000000
# 2026-07-13 18:06:05,044 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1100000000 step 1000000
# 2026-07-13 18:06:05,726 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1200000000 step 1000000
# 2026-07-13 18:06:06,403 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1300000000 step 1000000
# 2026-07-13 18:06:07,085 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1400000000 step 1000000
# 2026-07-13 18:06:07,774 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1500000000 step 1000000
# 2026-07-13 18:06:08,458 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1600000000 step 1000000
# 2026-07-13 18:06:09,146 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1700000000 step 1000000
# 2026-07-13 18:06:09,830 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1800000000 step 1000000
# 2026-07-13 18:06:10,518 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1900000000 step 1000000
# 2026-07-13 18:06:11,196 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2000000000 step 1000000
# 2026-07-13 18:06:11,894 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2100000000 step 1000000
# 2026-07-13 18:06:12,583 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2200000000 step 1000000
# 2026-07-13 18:06:13,270 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2300000000 step 1000000
# 2026-07-13 18:06:13,945 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2400000000 step 1000000
# 2026-07-13 18:06:14,623 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2500000000 step 1000000
# 2026-07-13 18:06:15,300 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2600000000 step 1000000
# 2026-07-13 18:06:15,989 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2700000000 step 1000000
# 2026-07-13 18:06:16,678 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2800000000 step 1000000
# 2026-07-13 18:06:17,357 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2900000000 step 1000000
# 2026-07-13 18:06:18,036 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3000000000 step 1000000
# 2026-07-13 18:06:18,713 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3100000000 step 1000000
# 2026-07-13 18:06:19,399 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3200000000 step 1282051
# 2026-07-13 18:06:39,031 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1000000000 step 1000000
# 2026-07-13 18:06:39,440 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1100000000 step 1000000
# 2026-07-13 18:06:40,118 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1200000000 step 1000000
# 2026-07-13 18:06:40,806 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1300000000 step 1000000
# 2026-07-13 18:06:41,494 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1400000000 step 1000000
# 2026-07-13 18:06:42,172 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1500000000 step 1000000
# 2026-07-13 18:06:42,849 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1600000000 step 1000000
# 2026-07-13 18:06:43,539 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1700000000 step 1000000
# 2026-07-13 18:06:44,218 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1800000000 step 1000000
# 2026-07-13 18:06:44,899 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1900000000 step 1000000
# 2026-07-13 18:06:45,578 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2000000000 step 1000000
# 2026-07-13 18:06:46,271 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2100000000 step 1000000
# 2026-07-13 18:06:46,960 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2200000000 step 1000000
# 2026-07-13 18:06:47,645 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2300000000 step 1000000
# 2026-07-13 18:06:48,330 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2400000000 step 1000000
# 2026-07-13 18:06:49,008 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2500000000 step 1000000
# 2026-07-13 18:06:49,689 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2600000000 step 1000000
# 2026-07-13 18:06:50,380 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2700000000 step 1000000
# 2026-07-13 18:06:51,073 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2800000000 step 1000000
# 2026-07-13 18:06:51,768 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2900000000 step 1000000
# 2026-07-13 18:06:52,446 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3000000000 step 1000000
# 2026-07-13 18:06:53,136 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3100000000 step 1000000
# 2026-07-13 18:06:53,813 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3200000000 step 1282051
# 2026-07-13 18:07:13,235 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1000000000 step 1000000
# 2026-07-13 18:07:13,638 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1100000000 step 1000000
# 2026-07-13 18:07:14,315 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1200000000 step 1000000
# 2026-07-13 18:07:15,004 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1300000000 step 1000000
# 2026-07-13 18:07:15,680 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1400000000 step 1000000
# 2026-07-13 18:07:16,370 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1500000000 step 1000000
# 2026-07-13 18:07:17,059 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1600000000 step 1000000
# 2026-07-13 18:07:17,740 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1700000000 step 1000000
# 2026-07-13 18:07:18,414 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1800000000 step 1000000
# 2026-07-13 18:07:19,091 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1900000000 step 1000000
# 2026-07-13 18:07:19,779 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2000000000 step 1000000
# 2026-07-13 18:07:20,455 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2100000000 step 1000000
# 2026-07-13 18:07:21,128 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2200000000 step 1000000
# 2026-07-13 18:07:21,812 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2300000000 step 1000000
# 2026-07-13 18:07:22,498 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2400000000 step 1000000
# 2026-07-13 18:07:23,175 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2500000000 step 1000000
# 2026-07-13 18:07:23,860 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2600000000 step 1000000
# 2026-07-13 18:07:24,551 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2700000000 step 1000000
# 2026-07-13 18:07:25,235 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2800000000 step 1000000
# 2026-07-13 18:07:25,921 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2900000000 step 1000000
# 2026-07-13 18:07:26,599 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3000000000 step 1000000
# 2026-07-13 18:07:27,276 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3100000000 step 1000000
# 2026-07-13 18:07:27,960 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3200000000 step 1282051
# 2026-07-13 18:07:47,632 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1000000000 step 1000000
# 2026-07-13 18:07:48,027 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1100000000 step 1000000
# 2026-07-13 18:07:48,704 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1200000000 step 1000000
# 2026-07-13 18:07:49,405 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1300000000 step 1000000
# 2026-07-13 18:07:50,088 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1400000000 step 1000000
# 2026-07-13 18:07:50,766 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1500000000 step 1000000
# 2026-07-13 18
- pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1700000000 step 1000000
# 2026-07-14 00:20:42,418 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1800000000 step 1000000
# 2026-07-14 00:20:43,109 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1900000000 step 1000000
# 2026-07-14 00:20:43,788 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2000000000 step 1000000
# 2026-07-14 00:20:44,461 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2100000000 step 1000000
# 2026-07-14 00:20:45,148 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2200000000 step 1000000
# 2026-07-14 00:20:45,835 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2300000000 step 1000000
# 2026-07-14 00:20:46,523 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2400000000 step 1000000
# 2026-07-14 00:20:47,198 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2500000000 step 1000000
# 2026-07-14 00:20:47,876 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2600000000 step 1000000
# 2026-07-14 00:20:48,555 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2700000000 step 1000000
# 2026-07-14 00:20:49,239 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2800000000 step 1000000
# 2026-07-14 00:20:49,921 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2900000000 step 1000000
# 2026-07-14 00:20:50,598 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3000000000 step 1000000
# 2026-07-14 00:20:51,275 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3100000000 step 1000000
# 2026-07-14 00:20:51,955 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3200000000 step 1282051
# 2026-07-14 00:27:29,232 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1000000000 step 1000000
# 2026-07-14 00:27:29,648 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1100000000 step 1000000
# 2026-07-14 00:27:30,336 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1200000000 step 1000000
# 2026-07-14 00:27:31,013 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1300000000 step 1000000
# 2026-07-14 00:27:31,690 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1400000000 step 1000000
# 2026-07-14 00:27:32,370 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1500000000 step 1000000
# 2026-07-14 00:27:33,057 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1600000000 step 1000000
# 2026-07-14 00:27:33,738 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1700000000 step 1000000
# 2026-07-14 00:27:34,415 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1800000000 step 1000000
# 2026-07-14 00:27:35,095 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1900000000 step 1000000
# 2026-07-14 00:27:35,773 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2000000000 step 1000000
# 2026-07-14 00:27:36,469 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2100000000 step 1000000
# 2026-07-14 00:27:37,163 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2200000000 step 1000000
# 2026-07-14 00:27:37,849 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2300000000 step 1000000
# 2026-07-14 00:27:38,538 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2400000000 step 1000000
# 2026-07-14 00:27:39,215 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2500000000 step 1000000
# 2026-07-14 00:27:39,898 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2600000000 step 1000000
# 2026-07-14 00:27:40,576 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2700000000 step 1000000
# 2026-07-14 00:27:41,253 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2800000000 step 1000000
# 2026-07-14 00:27:41,935 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2900000000 step 1000000
# 2026-07-14 00:27:42,613 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3000000000 step 1000000
# 2026-07-14 00:27:43,306 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3100000000 step 1000000
# 2026-07-14 00:27:44,001 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3200000000 step 1282051
# 2026-07-14 00:34:21,422 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1000000000 step 1000000
# 2026-07-14 00:34:21,816 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1100000000 step 1000000
# 2026-07-14 00:34:22,489 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1200000000 step 1000000
# 2026-07-14 00:34:23,170 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1300000000 step 1000000
# 2026-07-14 00:34:23,844 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1400000000 step 1000000
# 2026-07-14 00:34:24,521 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1500000000 step 1000000
# 2026-07-14 00:34:25,203 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1600000000 step 1000000
# 2026-07-14 00:34:25,889 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1700000000 step 1000000
# 2026-07-14 00:34:26,570 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1800000000 step 1000000
# 2026-07-14 00:34:27,247 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1900000000 step 1000000
# 2026-07-14 00:34:27,925 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2000000000 step 1000000
# 2026-07-14 00:34:28,611 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2100000000 step 1000000
# 2026-07-14 00:34:29,288 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2200000000 step 1000000
# 2026-07-14 00:34:29,966 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2300000000 step 1000000
# 2026-07-14 00:34:30,656 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2400000000 step 1000000
# 2026-07-14 00:34:31,342 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2500000000 step 1000000
# 2026-07-14 00:34:32,017 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2600000000 step 1000000
# 2026-07-14 00:34:32,703 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2700000000 step 1000000
# 2026-07-14 00:34:33,397 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2800000000 step 1000000
# 2026-07-14 00:34:34,077 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2900000000 step 1000000
# 2026-07-14 00:34:34,760 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3000000000 step 1000000
# 2026-07-14 00:34:35,439 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3100000000 step 1000000
# 2026-07-14 00:34:36,117 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3200000000 step 1282051
# 2026-07-14 00:40:39,220 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1000000000 step 1000000
# 2026-07-14 00:40:39,626 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1100000000 step 1000000
# 2026-07-14 00:40:40,305 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1200000000 step 1000000
# 2026-07-14 00:40:40,991 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1300000000 step 1000000
# 2026-07-14 00:40:41,668 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1400000000 step 1000000
# 2026-07-14 00:40:42,356 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1500000000 step 1000000
# 2026-07-14 00:40:43,034 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1600000000 step 1000000
# 2026-07-14 00:40:43,720 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1700000000 step 1000000
# 2026-07-14 00:40:44,403 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1800000000 step 1000000
# 2026-07-14 00:40:45,087 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1900000000 step 1000000
# 2026-07-14 00:40:45,768 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2000000000 step 1000000
# 2026-07-14 00:40:46,447 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2100000000 step 1000000
# 2026-07-14 00:40:47,125 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2200000000 step 1000000
# 2026-07-14 00:40:47,807 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2300000000 step 1000000
# 2026-07-14 00:40:48,496 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2400000000 step 1000000
# 2026-07-14 00:40:49,185 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2500000000 step 1000000
# 2026-07-14 00:40:49,863 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2600000000 step 1000000
# 2026-07-14 00:40:50,550 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2700000000 step 1000000
# 2026-07-14 00:40:51,237 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2800000000 step 1000000
# 2026-07-14 00:40:51,927 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 2900000000 step 1000000
# 2026-07-14 00:40:52,603 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3000000000 step 1000000
# 2026-07-14 00:40:53,294 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3100000000 step 1000000
# 2026-07-14 00:40:53,972 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 3200000000 step 1282051
# 2026-07-14 00:47:31,413 - pynanovna.hardware.NanoVNA_V2 - INFO - NanoVNAV2: set sweep start 1000000000 step 1000000
# >>> Serial exception caught, sleep for 1s and continuing
# >>> Serial exception caught, sleep for 1s and continuing
# >>> Serial exception caught, sleep for 1s and continuing
# >>> Serial exception caught, sleep for 1s and continuing
# >>> Serial exception caught, sleep for 1s and continuing
# >>> Serial exception caught, sleep for 1s and continuing
# >>> Serial exception caught, sleep for 1s and continuing
# >>> Serial exception caught, sleep for 1s and continuing
# >>> Serial exception caught, sleep for 1s and continuing
# >>> Serial exception caught, sleep for 1s and continuing
# >>> Serial exception caught, sleep for 1s and continuing
# >>> Serial exception caught, sleep for 1s and continuing
# >>> Serial exception caught, sleep for 1s and continuing
# >>> Serial exception caught, sleep for 1s and continuing
# >>> Serial exception caught, sleep for 1s and continuing
# >>> Serial exception caught, sleep for 1s and continuing
# >>> Serial exception caught, sleep for 1s and continuing
# >>> Serial exception caught, sleep for 1s and continuing
# >>> Serial exception caught, sleep for 1s and continuing
